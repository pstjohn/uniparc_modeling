# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context='talk', style='ticks',
        color_codes=True, rc={'legend.frameon': False})

# %matplotlib inline

# %%
import sys
sys.path.append('/ccs/home/pstjohn/uniparc_modeling')

from bert.go import Ontology
ont = Ontology()

# %%
ont.total_nodes
# Out:
# 32012

# %%
import os
dg_dir = '/ccs/home/pstjohn/project_work/deepgreen'
seq_df = pd.read_parquet(os.path.join(dg_dir, 'setaria.parquet'))
go_results = np.load('/ccs/home/pstjohn/member_work/setaria_go.npz')
dg_accessions = np.load('deepgreen_accessions.npz')['dg_list']

# %%
go_df = pd.DataFrame(np.vstack([go_results['protein'], go_results['go']]).T, columns=['protein_idx', 'go_idx'])

go_df = go_df.merge(seq_df['accession'], left_on='protein_idx', right_index=True)\
    .merge(pd.Series(ont.term_index, name='GO'), left_on='go_idx', right_index=True).sort_index()

# %%
go_df.head()
# Out:
#    protein_idx  go_idx   accession          GO
# 0            0       6  A0A0U2HKN4  GO:0008150
# 1            0      53  A0A0U2HKN4  GO:0005488
# 2            0      67  A0A0U2HKN4  GO:0003723
# 3            0      70  A0A0U2HKN4  GO:0043604
# 4            0      71  A0A0U2HKN4  GO:1901566

# %%
from scipy.stats import hypergeom

# %%
go_df.accession.isin(dg_accessions).sum()
# Out:
# 20581

# %%
go_df.head()
# Out:
#    protein_idx  go_idx   accession          GO
# 0            0       6  A0A0U2HKN4  GO:0008150
# 1            0      53  A0A0U2HKN4  GO:0005488
# 2            0      67  A0A0U2HKN4  GO:0003723
# 3            0      70  A0A0U2HKN4  GO:0043604
# 4            0      71  A0A0U2HKN4  GO:1901566

# %%
len(go_counts_background)
# Out:
# 3801

# %%
go_counts_background = go_df.GO.value_counts()
go_counts_deepgreen = go_df[go_df.accession.isin(dg_accessions)].GO.value_counts()

# %% [markdown]
# * M: total number of background genes
# * n: number of background genes with given GO annotation
# * N: total number of selected genes
# * x: number of selected genes with GO annotation

# %%
merged_go_counts = pd.DataFrame(go_counts_deepgreen).merge(
    go_counts_background, left_index=True, right_index=True,
    how='left', suffixes=['_dg', '_bg'])

M = len(go_df.accession.unique())  # Total number of background genes
N = len(dg_accessions)

merged_go_counts['p_val'] = merged_go_counts.apply(
    lambda row: hypergeom.sf(row.GO_dg - 1, M, row.GO_bg, N, loc=0), 1)

merged_go_counts['fold_enrichment'] = merged_go_counts.apply(
    lambda row: (row.GO_dg / N) / (row.GO_bg / M), 1)

merged_go_counts['significant'] = merged_go_counts.p_val < (0.05 / len(merged_go_counts))
merged_go_counts.sort_values('p_val').head()
# Out:
#             GO_dg  GO_bg         p_val  fold_enrichment  significant
# GO:0031224    379   8302  1.695433e-47         1.994694         True
# GO:0016021    379   8302  1.695433e-47         1.994694         True
# GO:0016020    399   9415  1.493978e-42         1.851708         True
# GO:0005886    146   2284  9.164595e-30         2.793037         True
# GO:0031090    185   3488  8.154656e-28         2.317475         True

# %%
go_descriptions = pd.DataFrame.from_dict(dict(ont.G.nodes(data=True)), orient='index').drop('index', 1)

# %%
merged_go_counts_with_descriptions = merged_go_counts.merge(go_descriptions, left_index=True, right_index=True, how='left')

# %%
merged_go_counts_with_descriptions.sort_values('p_val').head(30)
# Out:
#             GO_dg  GO_bg         p_val  fold_enrichment  significant  \
# GO:0031224    379   8302  1.695433e-47         1.994694         True
# GO:0016021    379   8302  1.695433e-47         1.994694         True
# GO:0016020    399   9415  1.493978e-42         1.851708         True
# GO:0005886    146   2284  9.164595e-30         2.793037         True
# GO:0031090    185   3488  8.154656e-28         2.317475         True
# GO:0046873     43    216  1.118942e-27         8.698304         True
# GO:0071805     25     54  6.250874e-27        20.228615         True
# GO:0098660     53    366  9.469229e-27         6.327245         True
# GO:0015079     23     44  1.790297e-26        22.839945         True
# GO:0006813     25     56  1.982589e-26        19.506164         True
# GO:0030001     45    292  4.925088e-24         6.733635         True
# GO:0008324     61    556  5.036754e-24         4.793745         True
# GO:0015075     61    556  5.036754e-24         4.793745         True
# GO:0022890     46    316  1.793636e-23         6.360491         True
# GO:0015318     64    649  1.228643e-22         4.308788         True
# GO:0034220     65    692  7.752751e-22         4.104187         True
# GO:0055085     99   1467  7.805791e-22         2.948662         True
# GO:0006811     70    799  1.013648e-21         3.827993         True
# GO:0098655     47    376  4.059418e-21         5.461726         True
# GO:0022857     96   1433  5.734790e-21         2.927150         True
# GO:0005215     96   1433  5.734790e-21         2.927150         True
# GO:0006812     48    427  1.365095e-19         4.911716         True
# GO:0031966     64    754  3.030743e-19         3.708758         True
# GO:0098662     41    316  3.500926e-19         5.669133         True
# GO:0015077     31    178  1.510365e-18         7.609596         True
# GO:1902600     29    162  8.895411e-18         7.821731         True
# GO:0015672     29    169  2.932371e-17         7.497754         True
# GO:0005739    107   2010  4.519459e-16         2.325989         True
# GO:0009507     73   1125  2.004140e-15         2.835243         True
# GO:0009536     73   1125  2.004140e-15         2.835243         True
#
#                                                          name  \
# GO:0031224                    intrinsic component of membrane
# GO:0016021                     integral component of membrane
# GO:0016020                                           membrane
# GO:0005886                                    plasma membrane
# GO:0031090                                 organelle membrane
# GO:0046873       metal ion transmembrane transporter activity
# GO:0071805              potassium ion transmembrane transport
# GO:0098660              inorganic ion transmembrane transport
# GO:0015079   potassium ion transmembrane transporter activity
# GO:0006813                            potassium ion transport
# GO:0030001                                metal ion transport
# GO:0008324          cation transmembrane transporter activity
# GO:0015075             ion transmembrane transporter activity
# GO:0022890  inorganic cation transmembrane transporter act...
# GO:0015318  inorganic molecular entity transmembrane trans...
# GO:0034220                        ion transmembrane transport
# GO:0055085                            transmembrane transport
# GO:0006811                                      ion transport
# GO:0098655                     cation transmembrane transport
# GO:0022857                 transmembrane transporter activity
# GO:0005215                               transporter activity
# GO:0006812                                   cation transport
# GO:0031966                             mitochondrial membrane
# GO:0098662           inorganic cation transmembrane transport
# GO:0015077  monovalent inorganic cation transmembrane tran...
# GO:1902600                     proton transmembrane transport
# GO:0015672              monovalent inorganic cation transport
# GO:0005739                                      mitochondrion
# GO:0009507                                        chloroplast
# GO:0009536                                            plastid
#
#                      namespace
# GO:0031224  cellular_component
# GO:0016021  cellular_component
# GO:0016020  cellular_component
# GO:0005886  cellular_component
# GO:0031090  cellular_component
# GO:0046873  molecular_function
# GO:0071805  biological_process
# GO:0098660  biological_process
# GO:0015079  molecular_function
# GO:0006813  biological_process
# GO:0030001  biological_process
# GO:0008324  molecular_function
# GO:0015075  molecular_function
# GO:0022890  molecular_function
# GO:0015318  molecular_function
# GO:0034220  biological_process
# GO:0055085  biological_process
# GO:0006811  biological_process
# GO:0098655  biological_process
# GO:0022857  molecular_function
# GO:0005215  molecular_function
# GO:0006812  biological_process
# GO:0031966  cellular_component
# GO:0098662  biological_process
# GO:0015077  molecular_function
# GO:1902600  biological_process
# GO:0015672  biological_process
# GO:0005739  cellular_component
# GO:0009507  cellular_component
# GO:0009536  cellular_component

# %%
merged_go_counts_with_descriptions.sort_values('p_val').to_csv('go_enrichment_results.csv')
